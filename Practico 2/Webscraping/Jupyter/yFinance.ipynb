# %%
# !pip install yfinance
import yfinance as yf
import pandas as pd
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.64.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=0.24 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: numpy>=1.15 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from yfinance) (1.21.3)
# Requirement already satisfied: requests>=2.20 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from yfinance) (2.26.0)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.9-py3-none-any.whl
# Requirement already satisfied: lxml>=4.5.1 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from requests>=2.20->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.26.7)
# Requirement already satisfied: six>=1.5 in /home/eleana/Documents/git/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.16.0)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.64-py2.py3-none-any.whl size=24109 sha256=a22b62b52af8a51e123806a89de552db4c132ec0bf86793ca41f7e306ce80b44
#   Stored in directory: /home/eleana/.cache/pip/wheels/f9/e9/7e/8b13db3bf3aeb5049d759e10702736fb96753089ac950fddc0
# Successfully built yfinance
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.9 yfinance-0.1.64

# %%
def cotizaciones_yf(tickers, fecha_inicio, fecha_final):
  df = yf.download(tickers, start=fecha_inicio, end=fecha_final,group_by="ticker")
  return df

# %%
if __name__ == "__main__":
  amzn = cotizaciones_yf("AMZN", "2021-10-03", "2021-10-05")
  amzn.to_csv('csv/amzn.csv', index = False)
  print(amzn)
  ticker = yf.Ticker('YPF')
  amzn_df = ticker.history(period="1y")
  amzn_df['Close'].plot(title="YPF SA stock price")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open        High      Low        Close    Adj Close  \
# Date
# 2021-10-04  3279.389893  3279.98999  3176.25  3189.780029  3189.780029
#
#              Volume
# Date
# 2021-10-04  4523100
