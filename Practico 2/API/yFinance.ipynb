# %%
# !pip install yfinance
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: yfinance in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (0.1.64)
# Requirement already satisfied: pandas>=0.24 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: multitasking>=0.0.7 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from yfinance) (1.21.4)
# Requirement already satisfied: lxml>=4.5.1 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from yfinance) (4.6.4)
# Requirement already satisfied: requests>=2.20 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: pytz>=2017.3 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from requests>=2.20->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.0.7)
# Requirement already satisfied: six>=1.5 in /home/eleana/Documents/git/practica/pp12021grupo2_a1-pp12021grupo2_a1/jupyter/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.16.0)

# %%
def cotizaciones_yf(tickers):
  df = yf.download(tickers,group_by="ticker", period='1d')
  return df

# %%
if __name__ == "__main__":
  bbva = cotizaciones_yf("BBVA")
  bbva.to_csv('csv/yFbbva.csv', index = False)

  tel = cotizaciones_yf("TEF.MC")
  tel.to_csv('csv/yFTEL.csv', index = False)

  san = cotizaciones_yf("SAN.MC")
  san.to_csv('csv/yFSAN.csv', index = False)

  ticker = yf.Ticker('BBVA');
  bbva_df = ticker.history(interval="1d");

  ticker = yf.Ticker('TEF');
  tel_df = ticker.history(interval="1d");

  ticker = yf.Ticker('SAN');
  san_df = ticker.history(interval="1d");
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(20,5))
plt.subplot(131)
bbva_df['High'].plot(title="BBVA.MC", marker="*", color='#01b8aa', label="Maximo");
bbva_df['Low'].plot(title="BBVA.MC", marker="*", color='#fd625e', label="Minimo");
plt.legend()
plt.subplot(132)
tel_df['High'].plot(title="TEF.MC", marker="*",color='#01b8aa', label="Maximo");
tel_df['Low'].plot(title="TEF.MC", marker="*", color='#fd625e', label="Minimo");
plt.legend()
plt.subplot(133)
san_df['High'].plot(title="SAN.MC",marker="*", color='#01b8aa', label="Maximo");
san_df['Low'].plot(title="SAN.MC", marker="*", color='#fd625e', label="Minimo");
plt.legend()
plt.show();
